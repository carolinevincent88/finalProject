# %%
import pip._vendor.requests
import pandas as pd
import json
import urllib
import geopy
from geopy.geocoders import Nominatim
import geopandas
import plotly
import plotly.express as px
import nbformat 
from shapely.geometry import Point

# %%
url = "https://data.cambridgema.gov/resource/xuad-73uj.json?$limit=800"
uh = urllib.request.urlopen(url)
data = uh.read().decode()
print('Retrieved', len(data), 'characters')
# Out:
# Retrieved 193427 characters

# %%
#load data to a dictionary
myData = json.loads(data)

#load myData into a DataFrame object
df = pd.DataFrame(myData)

#replace Ma with Massachusetts for every address in df['location']
df['location'] = df['location'].str.replace(', MA', ', Massachusetts')

#print the first 5 rows of df
df.head()
# Out:
#   file_number           date_of_report                      crime_date_time  \
# 0  2023-02647  2023-03-31T22:52:00.000  03/30/2023 16:00 - 03/31/2023 22:52
# 1  2023-02643  2023-03-31T20:39:00.000                     03/31/2023 20:36
# 2  2023-02640  2023-03-31T18:14:00.000  03/29/2023 20:00 - 03/31/2023 18:00
# 3  2023-02634  2023-03-31T13:27:00.000                     03/26/2023 17:30
# 4  2023-02630  2023-03-31T10:36:00.000             03/30/2023 18:00 - 23:00
#
#                 crime reporting_area     neighborhood  \
# 0          Auto Theft            506    Cambridgeport
# 1  Aggravated Assault           1101  North Cambridge
# 2     Larceny from MV            508    Cambridgeport
# 3      Street Robbery           1002   West Cambridge
# 4          Auto Theft            901          Peabody
#
#                                             location
# 0  Lopez St & Brookline St, Cambridge, Massachusetts
# 1  MASSACHUSETTS AVE & SOMERVILLE AVE, Cambridge,...
# 2           500 PUTNAM AVE, Cambridge, Massachusetts
# 3   BRATTLE ST & Church St, Cambridge, Massachusetts
# 4  GARDEN ST & MASSACHUSETTS AVE, Cambridge, Mass...

# %%
locator = Nominatim(user_agent="myGeocoder", timeout=10)

#create columns for latitude and longitude
df['latitude'] = ""
df['longitude'] = ""

#loop through each row of the DataFrame and geocode the address
for index, row in df.iterrows():
    location = locator.geocode(row['location'])
    if location:
        df.at[index, 'latitude'] = location.latitude
        df.at[index, 'longitude'] = location.longitude
    else:
        df.at[index, 'latitude'] = ""
        df.at[index, 'longitude'] = ""

#drop rows with no latitude or longitude
df = df[df['latitude'] != ""]
df = df[df['longitude'] != ""]
df.head()
# Out:
#   file_number           date_of_report                      crime_date_time  \
# 2  2023-02640  2023-03-31T18:14:00.000  03/29/2023 20:00 - 03/31/2023 18:00
# 4  2023-02630  2023-03-31T10:36:00.000             03/30/2023 18:00 - 23:00
# 5  2023-02614  2023-03-30T17:27:00.000             03/29/2023 14:56 - 15:40
# 6  2023-02612  2023-03-30T17:20:00.000                     03/30/2023 17:19
# 7  2023-02618  2023-03-30T17:10:00.000                     03/30/2023 13:29
#
#                     crime reporting_area    neighborhood  \
# 2         Larceny from MV            508   Cambridgeport
# 4              Auto Theft            901         Peabody
# 5  Larceny from Residence            107  East Cambridge
# 6      Commercial Robbery           1204       Highlands
# 7  Larceny from Residence            504   Cambridgeport
#
#                                             location   latitude  longitude
# 2           500 PUTNAM AVE, Cambridge, Massachusetts  42.358253 -71.109385
# 4  GARDEN ST & MASSACHUSETTS AVE, Cambridge, Mass...  42.378372 -71.123878
# 5              100 GORE ST, Cambridge, Massachusetts  42.371887  -71.08232
# 6    200 Alewife Brook Pky, Cambridge, Massachusetts  42.388369 -71.142954
# 7               0 PEARL ST, Cambridge, Massachusetts  42.364644 -71.102668

# %%
#count the number of rows at each location
df['count'] = df.groupby(['latitude', 'longitude'])['latitude'].transform('count')

#print the first 25 rows of df
df.head(25)
# Out:
#    file_number           date_of_report                      crime_date_time  \
# 2   2023-02640  2023-03-31T18:14:00.000  03/29/2023 20:00 - 03/31/2023 18:00
# 4   2023-02630  2023-03-31T10:36:00.000             03/30/2023 18:00 - 23:00
# 5   2023-02614  2023-03-30T17:27:00.000             03/29/2023 14:56 - 15:40
# 6   2023-02612  2023-03-30T17:20:00.000                     03/30/2023 17:19
# 7   2023-02618  2023-03-30T17:10:00.000                     03/30/2023 13:29
# 8   2023-02608  2023-03-30T15:26:00.000             03/30/2023 15:25 - 15:30
# 9   2023-02603  2023-03-30T13:59:00.000  03/23/2023 14:02 - 03/30/2023 13:58
# 10  2023-02600  2023-03-30T12:51:00.000             03/30/2023 11:00 - 12:00
# 11  2023-02599  2023-03-30T12:17:00.000                     03/30/2023 12:16
# 12  2023-02593  2023-03-30T07:52:00.000  03/29/2023 20:00 - 03/30/2023 07:00
# 13  2023-02578  2023-03-29T16:20:00.000             03/29/2023 16:05 - 16:19
# 14  2023-02576  2023-03-29T16:03:00.000                     03/29/2023 16:02
# 15  2023-02577  2023-03-29T16:00:00.000             03/29/2023 15:20 - 15:25
# 16  2023-02574  2023-03-29T15:19:00.000             03/29/2023 12:00 - 15:18
# 17  2023-02579  2023-03-29T14:16:00.000             03/12/2023 14:00 - 15:00
# 18  2023-02568  2023-03-29T13:40:00.000  02/22/2023 13:43 - 03/21/2023 13:43
# 19  2023-02569  2023-03-29T13:35:00.000  03/01/2023 13:15 - 03/29/2023 11:20
# 20  2023-02567  2023-03-29T11:35:00.000  03/28/2023 22:15 - 03/29/2023 11:35
# 21  2023-02564  2023-03-29T11:00:00.000             03/27/2023 02:36 - 02:55
# 22  2023-02549  2023-03-28T19:08:00.000                     03/28/2023 19:07
# 23  2023-02550  2023-03-28T17:20:00.000             03/28/2023 08:30 - 13:00
# 24  2023-02543  2023-03-28T16:35:00.000                     03/28/2023 16:35
# 25  2023-02540  2023-03-28T15:57:00.000                     03/26/2023 18:06
# 26  2023-02541  2023-03-28T15:32:00.000             03/20/2023 08:30 - 15:00
# 27  2023-02536  2023-03-28T14:48:00.000  03/21/2023 17:21 - 03/28/2023 14:47
#
#                      crime reporting_area      neighborhood  \
# 2          Larceny from MV            508     Cambridgeport
# 4               Auto Theft            901           Peabody
# 5   Larceny from Residence            107    East Cambridge
# 6       Commercial Robbery           1204         Highlands
# 7   Larceny from Residence            504     Cambridgeport
# 8              Shoplifting            411            Area 4
# 9                Flim Flam            104    East Cambridge
# 10       Weapon Violations            304  Inman/Harrington
# 11             Shoplifting            501     Cambridgeport
# 12      Larceny of Bicycle            301  Inman/Harrington
# 13             Shoplifting            501     Cambridgeport
# 14      Commercial Robbery            610     Mid-Cambridge
# 15             Shoplifting           1002    West Cambridge
# 16   Larceny from Building           1017    West Cambridge
# 17  Larceny from Residence            101    East Cambridge
# 18                 Forgery           1101   North Cambridge
# 19   Larceny from Building           1101   North Cambridge
# 20     Mal. Dest. Property           1109   North Cambridge
# 21              Housebreak            108    East Cambridge
# 22  Larceny from Residence            604     Mid-Cambridge
# 23      Larceny of Bicycle            606     Mid-Cambridge
# 24             Shoplifting            501     Cambridgeport
# 25             Shoplifting            501     Cambridgeport
# 26      Larceny of Bicycle            706         Riverside
# 27   Larceny from Building           1101   North Cambridge
#
#                                              location   latitude  longitude  \
# 2            500 PUTNAM AVE, Cambridge, Massachusetts  42.358253 -71.109385
# 4   GARDEN ST & MASSACHUSETTS AVE, Cambridge, Mass...  42.378372 -71.123878
# 5               100 GORE ST, Cambridge, Massachusetts  42.371887  -71.08232
# 6     200 Alewife Brook Pky, Cambridge, Massachusetts  42.388369 -71.142954
# 7                0 PEARL ST, Cambridge, Massachusetts  42.364644 -71.102668
# 8     600 MASSACHUSETTS AVE, Cambridge, Massachusetts  42.364916 -71.103308
# 9            300 WINDSOR ST, Cambridge, Massachusetts  42.368865 -71.094636
# 10         800 CAMBRIDGE ST, Cambridge, Massachusetts   42.37223 -71.089916
# 11    600 MASSACHUSETTS AVE, Cambridge, Massachusetts  42.364916 -71.103308
# 12             0 HUNTING ST, Cambridge, Massachusetts  42.373378 -71.090988
# 13    600 MASSACHUSETTS AVE, Cambridge, Massachusetts  42.364916 -71.103308
# 14             300 BROADWAY, Cambridge, Massachusetts  42.368834 -71.099563
# 15             0 BRATTLE ST, Cambridge, Massachusetts   42.37589 -71.142096
# 16      300 Mount Auburn St, Cambridge, Massachusetts   42.37476 -71.132829
# 17               0 CHILD ST, Cambridge, Massachusetts  42.372165   -71.0722
# 18             100 White St, Cambridge, Massachusetts  42.388646 -71.118909
# 19   2000 MASSACHUSETTS AVE, Cambridge, Massachusetts  42.390298 -71.121372
# 20             0 CLIFTON PL, Cambridge, Massachusetts  42.393149 -71.136224
# 21              0 ROGERS ST, Cambridge, Massachusetts  42.366106 -71.079811
# 22        1500 CAMBRIDGE ST, Cambridge, Massachusetts  42.374055  -71.10468
# 23             500 BROADWAY, Cambridge, Massachusetts  42.375042 -71.114652
# 24    600 MASSACHUSETTS AVE, Cambridge, Massachusetts  42.364916 -71.103308
# 25    600 MASSACHUSETTS AVE, Cambridge, Massachusetts  42.364916 -71.103308
# 26           100 PUTNAM AVE, Cambridge, Massachusetts  42.366874 -71.113412
# 27       800 SOMERVILLE AVE, Cambridge, Massachusetts  42.388734 -71.119645
#
#     count
# 2       1
# 4       2
# 5       3
# 6      13
# 7       4
# 8      74
# 9       1
# 10      2
# 11     74
# 12      1
# 13     74
# 14      4
# 15      7
# 16      3
# 17      1
# 18     15
# 19      2
# 20      2
# 21      1
# 22      5
# 23      5
# 24     74
# 25     74
# 26      5
# 27     13

# %%
px.set_mapbox_access_token(open(".mapbox_token").read())

# %%
fig = px.scatter_mapbox(df,
                        lat='latitude',
                        lon='longitude',
                        hover_name='location',
                        mapbox_style='open-street-map',
                        zoom=11,)
fig.update_layout(title='Cambridge Crime Map',
                  autosize=True,
                  hovermode='closest',
                  showlegend=False,
                  )

#update fig to color by df['count']
fig.update_traces(marker=dict(size=6,
                                color=df['count'],
                                colorscale='ylorrd_r',
                                opacity=.8,
                                reversescale=True,
                                colorbar_title='Number of Crimes',
                                ),
                    selector=dict(mode='markers')
                    )



#update fig to show the number of crimes in the hover text
fig.update_traces(hovertemplate='<b>%{hovertext}</b><br><br>' +
                                'Number of Crimes: %{marker.color}<br>' +
                                '<extra></extra>'
                                )


fig.show()
# Out:
# <div>                            <div id="40e6a25c-7fb2-4cf9-840e-8789839d6bad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("40e6a25c-7fb2-4cf9-840e-8789839d6bad")) {                    Plotly.newPlot(                        "40e6a25c-7fb2-4cf9-840e-8789839d6bad",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>Number of Crimes: %{marker.color}<br><extra></extra>","hovertext":["500 PUTNAM AVE, Cambridge, Massachusetts","GARDEN ST & MASSACHUSETTS AVE, Cambridge, Massachusetts","100 GORE ST, Cambridge, Massachusetts","200 Alewife Brook Pky, Cambridge, Massachusetts","0 PEARL ST, Cambridge, Massachusetts","600 MASSACHUSETTS AVE, Cambridge, Massachusetts","300 WINDSOR ST, Cambridge, Massachusetts","800 CAMBRIDGE ST, Cambridge, Massachusetts","600 MASSACHUSETTS AVE, Cambridge, Massachusetts","0 HUNTING ST, Cambridge, Massachusetts","600 MASSACHUSETTS AVE, Cambridge, Massachusetts","300 BROADWAY, Cambridge, Massachusetts","0 BRATTLE ST, Cambridge, Massachusetts","300 Mount Auburn St, Cambridge, Massachusetts","0 CHILD ST, Cambridge, Massachusetts","100 White St, Cambridge, Massachusetts","2000 MASSACHUSETTS AVE, Cambridge, Massachusetts","0 CLIFTON PL, Cambridge, Massachusetts","0 ROGERS ST, Cambridge, Massachusetts","1500 CAMBRIDGE ST, Cambridge, Massachusetts","500 BROADWAY, Cambridge, Massachusetts","600 MASSACHUSETTS AVE, Cambridge, Massachusetts","600 MASSACHUSETTS AVE, Cambridge, Massachusetts","100 PUTNAM AVE, Cambridge, Massachusetts","800 SOMERVILLE AVE, Cambridge, Massachusetts","100 HIGHLAND AVE, Cambridge, Massachusetts","AUBURN ST & MAGAZINE ST, Cambridge, Massachusetts","1400 MASSACHUSETTS AVE, Cambridge, Massachusetts","0 WARE ST, Cambridge, Massachusetts","BROOKLINE ST & FRANKLIN ST, Cambridge, Massachusetts","100 HARVARD ST, Cambridge, Massachusetts","200 GREEN ST, Cambridge, Massachusetts","1800 MASSACHUSETTS AVE, Cambridge, Massachusetts","0 White St, Cambridge, Massachusetts","100 SHERMAN ST, Cambridge, Massachusetts","400 RINDGE AVE, Cambridge, Massachusetts","800 MAIN ST, Cambridge, Massachusetts","200 HURLEY ST, Cambridge, Massachusetts","0 GORE ST, Cambridge, Massachusetts","0 GARDEN ST, Cambridge, Massachusetts","1600 CAMBRIDGE ST, Cambridge, Massachusetts","0 KELLEY ST, Cambridge, Massachusetts","800 MASSACHUSETTS AVE, Cambridge, Massachusetts","300 PROSPECT ST, Cambridge, Massachusetts","0 CENTRAL SQ, Cambridge, Massachusetts","1800 MASSACHUSETTS AVE, Cambridge, Massachusetts","1800 MASSACHUSETTS AVE, Cambridge, Massachusetts","0 BANCROFT ST, Cambridge, Massachusetts","100 BISHOP ALLEN DR, Cambridge, Massachusetts","0 MARNEY ST, Cambridge, Massachusetts","0 PORTER ST, Cambridge, Massachusetts","0 ST MARY RD, Cambridge, Massachusetts","100 CAMBRIDGEPARK DR, Cambridge, Massachusetts","100 LINCOLN ST, Cambridge, Massachusetts","100 CAMBRIDGEPARK DR, Cambridge, Massachusetts","1900 MASSACHUSETTS AVE, Cambridge, Massachusetts","2100 MASSACHUSETTS AVE, Cambridge, Massachusetts","200 NORTH FIRST ST, Cambridge, Massachusetts","600 MASSACHUSETTS AVE, Cambridge, Massachusetts","200 WESTERN AVE, Cambridge, Massachusetts","0 HOLYOKE PL, Cambridge, Massachusetts","100 Cambridgeside Pl, Cambridge, Massachusetts","900 MASSACHUSETTS AVE, Cambridge, Massachusetts","1400 Massachusetts Ave, Cambridge, Massachusetts","600 MASSACHUSETTS AVE, Cambridge, Massachusetts","100 JACKSON ST, Cambridge, Massachusetts","0 CAMBRIDGEPARK DR, Cambridge, Massachusetts","0 EDUCATION CIR, Cambridge, Massachusetts","1000 MASSACHUSETTS AVE, Cambridge, Massachusetts","WILLOW ST & Cambridge St, Cambridge, Massachusetts","Green St & Magazine St, Cambridge, Massachusetts","800 CAMBRIDGE ST, Cambridge, Massachusetts","0 WHITE ST, Cambridge, Massachusetts","0 WARE ST, Cambridge, Massachusetts ...
